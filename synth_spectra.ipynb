# %%
import numpy as np 
import matplotlib.pyplot as plt 
import h5py
import calc_op_em as coe

# %%
# Read a model atmosphere from an HDF5 file
filename = '/dat/milic/SUSI_modeling/extended_cube.h5'

# Do a lazy way of reading without putting everything in memory at once: 

with h5py.File(filename, 'r') as f:
    Temp = f['Temperature']
    print ("info::shape of the temperature array is: ", Temp.shape)  # Check the shape of the dataset

#with h5py.File(filename, 'r') as f:
#    T = f['Temperature'][:]  # Temperature in K
#    pgas = f['Pressure'][:]  # Pressure in dyne/cm^2
#    ne = f['Electron_density'][:]  # Electron density
#    v_los = f['LOS_velocity'][:]  # Line-of-sight velocity in cm/s
#    pop_lower = f['Population_lower_level'][:]  # Population of lower level
#    pop_upper = f['Population_upper_level'][:]  # Population of upper level
