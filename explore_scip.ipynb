# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
s1 = fits.open('/dat/milic/SUNRISE_III/SCIP/data/sunrise/2024/DataPublic/17_LIMB/scip/17_LIMB.SC_00_SP1_L10/2024_07_13_22_13_45_623_SP1_I_v3.1.fits')

# %%
s1.info()
# Out:
# Filename: /dat/milic/SUNRISE_III/SCIP/data/sunrise/2024/DataPublic/17_LIMB/scip/17_LIMB.SC_00_SP1_L10/2024_07_13_22_13_45_623_SP1_I_v3.1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     218   (2150, 640)   float64

# %%
plt.figure(figsize=(15,4))
plt.imshow(s1[0].data,vmin=0, vmax=5E5, origin='lower')
plt.xlim(750,2100)
plt.ylim(250,50)
plt.colorbar()
